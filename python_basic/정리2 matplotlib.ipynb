# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([])
for i in range(5):
    for j in range(1):
        globals()[f'df{i}'] = pd.DataFrame({i:range(0,30)})
    globals()[f'df{i}']+i
    df = pd.concat([df, globals()[f'df{i}']], axis=1)

# %%
df[0] = df[0] + 500
df[1] = df[1] + 700
df[2] = df[2] * 40
df[3] = df[3] ** 2
df
# Out:
#       0    1     2    3   4
# 0   500  700     0    0   0
# 1   501  701    40    1   1
# 2   502  702    80    4   2
# 3   503  703   120    9   3
# 4   504  704   160   16   4
# 5   505  705   200   25   5
# 6   506  706   240   36   6
# 7   507  707   280   49   7
# 8   508  708   320   64   8
# 9   509  709   360   81   9
# 10  510  710   400  100  10
# 11  511  711   440  121  11
# 12  512  712   480  144  12
# 13  513  713   520  169  13
# 14  514  714   560  196  14
# 15  515  715   600  225  15
# 16  516  716   640  256  16
# 17  517  717   680  289  17
# 18  518  718   720  324  18
# 19  519  719   760  361  19
# 20  520  720   800  400  20
# 21  521  721   840  441  21
# 22  522  722   880  484  22
# 23  523  723   920  529  23
# 24  524  724   960  576  24
# 25  525  725  1000  625  25
# 26  526  726  1040  676  26
# 27  527  727  1080  729  27
# 28  528  728  1120  784  28
# 29  529  729  1160  841  29

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(df)
plt.bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1857/1988324844.py in <module>
#       1 fig = plt.figure(figsize=(10,10))
#       2 plt.plot(df)
# ----> 3 plt.bar(df)
#       4 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df0 = pd.DataFrame(range(30))
df1 = pd.DataFrame(range(30))

# %%
pd.concat([df0, df1], axis=1)
# Out:
#      0   0
# 0    0   0
# 1    1   1
# 2    2   2
# 3    3   3
# 4    4   4
# 5    5   5
# 6    6   6
# 7    7   7
# 8    8   8
# 9    9   9
# 10  10  10
# 11  11  11
# 12  12  12
# 13  13  13
# 14  14  14
# 15  15  15
# 16  16  16
# 17  17  17
# 18  18  18
# 19  19  19
# 20  20  20
# 21  21  21
# 22  22  22
# 23  23  23
# 24  24  24
# 25  25  25
# 26  26  26
# 27  27  27
# 28  28  28
# 29  29  29
